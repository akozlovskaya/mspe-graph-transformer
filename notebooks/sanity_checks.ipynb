# %% [markdown]
# # Sanity Checks for Multi-Scale Positional Encodings
#
# This notebook contains sanity checks and exploratory analysis for the positional encoding implementations.

# %%
# TODO: Add sanity check cells
import torch
import numpy as np
import matplotlib.pyplot as plt
